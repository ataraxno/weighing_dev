# %%
import os
import glob

import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)
from sklearn.utils import shuffle

from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import *
import tensorflow_addons as tfa
tf.__version__
# Out:
# '2.3.0'

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import (LinearLocator, MultipleLocator, FormatStrFormatter)
from matplotlib.dates import MONDAY
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
from matplotlib import gridspec
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %% [markdown]
# # Hyperparameters

# %%
BEST_PATH = './models/Transformer.h5'
TRAINING_EPOCHS = 200
LEARNING_RATE = 0.002
EPSILON = 1e-06
BATCH_SIZE = 16

# %% [markdown]
# # Data loading

# %%
l = np.load('./results/2020_S/fw_dataset.npz', allow_pickle=True)
data_indices = l['data_indices']
input_data = l['input_data']
output_label = l['output_label']
INPUT_MAXS = l['INPUT_MAXS']
INPUT_MINS = l['INPUT_MINS']
OUTPUT_MAX = l['OUTPUT_MAX']
OUTPUT_MIN = l['OUTPUT_MIN']

# %%
input_data = input_data.astype('float32')
output_label = output_label.astype('float32')

# %%
print(input_data.shape)
print(output_label.shape)
# Out:
# (363, 144, 9)
# (363, 1)

# %%
print(INPUT_MAXS)
print(INPUT_MINS)
# Out:
# [ 42.31875  90.9425  330.1      73.335    10.006     5.057    36.58
#   50.264    19.731  ]
# [15.83875  4.4325  -0.5957  32.115    2.296    0.579   15.7      8.744
#  11.393  ]

# %%
print(OUTPUT_MAX)
print(OUTPUT_MIN)
# Out:
# 2.470441467376113
# 0.40038664002968494

# %%
data_indices, input_data, output_label = shuffle(data_indices, input_data, output_label, random_state=3101)

# %%
N_TRAIN = int(input_data.shape[0]*.7)
train_input = input_data[:N_TRAIN, ...]
train_label = output_label[:N_TRAIN, ...]
train_indices = data_indices[:N_TRAIN]
val_input = input_data[N_TRAIN:, ...]
val_label = output_label[N_TRAIN:, ...]
val_indices = data_indices[N_TRAIN:]

# %%
print(f'number of training set: {train_input.shape[0]}')
print(f'number of validation set: {val_input.shape[0]}')
# Out:
# number of training set: 254
# number of validation set: 109

# %%
with strategy.scope():
    train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
    train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)
    val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
    val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)

# %%
print(train_input.shape)
print(train_label.shape)
# Out:
# (254, 144, 9)
# (254, 1)

# %% [markdown]
# # Model construction

# %%
class EmbeddingLayer(layers.Layer):
    def __init__(self, num_nodes):
        super(EmbeddingLayer, self).__init__()
        self.n = num_nodes
        
        self.dense = layers.Dense(self.n)
        self.norm = layers.LayerNormalization(epsilon=1e-6)
        
    def call(self, inp, is_train=True, **kwargs):
        
        inp = self.dense(inp)
        inp = self.norm(inp, training=is_train)

        return inp

# %%
class EncoderBlock(layers.Layer):
    def __init__(self, num_nodes, num_heads):
        super(EncoderBlock, self).__init__()
        self.n = num_nodes
        self.h = num_heads
        self.d = self.n // self.h
        
        self.wq = layers.Dense(self.n)
        self.wk = layers.Dense(self.n)
        self.wv = layers.Dense(self.n)
        
        self.dropout = layers.Dropout(0.1)
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        
        self.dense1 = layers.Dense(self.n, activation=tf.nn.relu)
        self.dense2 = layers.Dense(self.n)
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        
    def head_maker(self, x, axis_1=2, axis_2=0):
        x = tf.concat(tf.split(x, self.h, axis=axis_1), axis=axis_2)
        
        return x
    
    def call(self, inp, is_train=True, **kwargs):
        Q = self.head_maker(self.wq(inp))
        K = self.head_maker(self.wk(inp))
        V = self.head_maker(self.wv(inp))
        
        oup = tf.matmul(Q, tf.transpose(K, (0, 2, 1)))
        oup = oup / tf.math.sqrt(tf.cast(K.shape[-1], tf.float32))
        oup = tf.nn.softmax(oup)
        oup = self.dropout(oup, training=is_train)
        oup = tf.matmul(oup, V)
        oup = self.head_maker(oup, 0, 2)
        oup += inp
        oup = self.norm1(oup, training=is_train)
        
        oup_ffnn = self.dense1(oup)
        oup_ffnn = self.dense2(oup_ffnn)
        oup += oup_ffnn
        oup = self.norm2(oup, training=is_train)
        
        return oup

# %%
class TransformerLike(Model):
    def __init__(self, num_nodes, num_heads, num_layers):
        super(TransformerLike, self).__init__()
        self.n = num_nodes
        self.h = num_heads
        self.l = num_layers
        
        self.emb = EmbeddingLayer(self.n)
        self.encs = [EncoderBlock(self.n, self.h) for _ in range(self.l)]
        
        self.dense1 = layers.Dense(self.n, activation=tf.nn.relu)
        self.dense2 = layers.Dense(self.n, activation=tf.nn.relu)
        self.dense3 = layers.Dense(self.n, activation=tf.nn.relu)
        self.flatten = layers.Flatten()
        self.outdense = layers.Dense(1)        
        
    def call(self, inp, is_train=True, **kwargs):
        
        inp = self.emb(inp)
        for i in range(self.l):
            inp = self.encs[i](inp, training=is_train)
            
        inp = self.dense1(inp)
        inp = self.dense2(inp)
        inp = self.dense3(inp)
        inp = self.outdense(self.flatten(inp))
        
        return inp

# %%
callbacks = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=.5, patience=2, verbose=0, mode='min',
    min_delta=0.0001, cooldown=0, min_lr=0)

save = tf.keras.callbacks.ModelCheckpoint(
    BEST_PATH, monitor='val_loss', verbose=0,
    save_best_only=True, save_weights_only=True, mode='min', save_freq='epoch')

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=20)

# %%
with strategy.scope():
    opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE, epsilon=EPSILON)
    model = TransformerLike(128, 4, 2)
    model.compile(optimizer=opt, loss='mae')
    model.fit(train_dataset, epochs=TRAINING_EPOCHS, validation_data=val_dataset,
                  verbose=1, callbacks=[callbacks, save, early_stop])
# Out:
# Epoch 1/200
# WARNING:tensorflow:From /home/phil/.virtualenvs/tf20/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 40 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 40 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 16/16 [==============================] - ETA: 0s - loss: 1.7836INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 16/16 [==============================] - 2s 153ms/step - loss: 1.7836 - val_loss: 0.2104
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 2/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2760 - val_loss: 0.2220
# Epoch 3/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1787 - val_loss: 0.0876
# Epoch 4/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0726 - val_loss: 0.0537
# Epoch 5/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1254 - val_loss: 0.0368
# Epoch 6/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0519 - val_loss: 0.0519
# Epoch 7/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0363 - val_loss: 0.0601
# Epoch 8/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0433 - val_loss: 0.0246
# Epoch 9/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0343 - val_loss: 0.0445
# Epoch 10/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0353 - val_loss: 0.0312
# Epoch 11/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0254 - val_loss: 0.0218
# Epoch 12/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0262 - val_loss: 0.0162
# Epoch 13/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0210 - val_loss: 0.0200
# Epoch 14/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0293 - val_loss: 0.0395
# Epoch 15/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0253 - val_loss: 0.0209
# Epoch 16/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0186 - val_loss: 0.0226
# Epoch 17/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0187 - val_loss: 0.0136
# Epoch 18/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0146 - val_loss: 0.0184
# Epoch 19/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0143 - val_loss: 0.0132
# Epoch 20/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.0129 - val_loss: 0.0146
# Epoch 21/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0134 - val_loss: 0.0133
# Epoch 22/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0135 - val_loss: 0.0181
# Epoch 23/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0128 - val_loss: 0.0140
# Epoch 24/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0127 - val_loss: 0.0133
# Epoch 25/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0124 - val_loss: 0.0123
# Epoch 26/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0124 - val_loss: 0.0124
# Epoch 27/200
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 28/200
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0121 - val_loss: 0.0118
# Epoch 29/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0117 - val_loss: 0.0122
# Epoch 30/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0119 - val_loss: 0.0134
# Epoch 31/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0118 - val_loss: 0.0119
# Epoch 32/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0111 - val_loss: 0.0119
# Epoch 33/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0111 - val_loss: 0.0120
# Epoch 34/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 35/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0111 - val_loss: 0.0118
# Epoch 36/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0110 - val_loss: 0.0118
# Epoch 37/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0110 - val_loss: 0.0118
# Epoch 38/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0111 - val_loss: 0.0118
# Epoch 39/200
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0111 - val_loss: 0.0117
# Epoch 40/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 41/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0109 - val_loss: 0.0118
# Epoch 42/200
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 43/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0110 - val_loss: 0.0120
# Epoch 44/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0109 - val_loss: 0.0118
# Epoch 45/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0109 - val_loss: 0.0118
# Epoch 46/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0110 - val_loss: 0.0119
# Epoch 47/200
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 48/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0109 - val_loss: 0.0119
# Epoch 49/200
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0110 - val_loss: 0.0116
# Epoch 50/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 51/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0111 - val_loss: 0.0117
# Epoch 52/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 53/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0108 - val_loss: 0.0118
# Epoch 54/200
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0109 - val_loss: 0.0116
# Epoch 55/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0110 - val_loss: 0.0118
# Epoch 56/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0109 - val_loss: 0.0116
# Epoch 57/200
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 58/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 59/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0108 - val_loss: 0.0119
# Epoch 60/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0109 - val_loss: 0.0118
# Epoch 61/200
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 62/200
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0110 - val_loss: 0.0118
# Epoch 63/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 64/200
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0110 - val_loss: 0.0118
# Epoch 65/200
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0109 - val_loss: 0.0116
# Epoch 66/200
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0109 - val_loss: 0.0119
# Epoch 67/200
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0109 - val_loss: 0.0116
# Epoch 68/200
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 69/200
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0109 - val_loss: 0.0117

# %%
model.load_weights(BEST_PATH)

# %%
model.evaluate(val_dataset)
# Out:
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0115
# 0.01151809748262167

# %%
pred_output = model.predict(val_input)

# %%
pred_output = pred_output*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN
val_label = val_label*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(val_label, pred_output, 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df = pd.DataFrame(val_label, index=val_indices[:, 0], columns=['label'])
pred_df['pred'] = pred_output
pred_df.index = pd.DatetimeIndex(pred_df.index)
pred_df = pred_df.sort_index()

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(pred_df.index, pred_df['label'], '-o', ms=5, mec='k', c=cmap[4])
ax0.plot(pred_df.index, pred_df['pred'], 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df.to_csv('./results/model_output/transformer.csv')
