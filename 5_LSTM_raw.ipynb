# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)
from sklearn.utils import shuffle

from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import *
import tensorflow_addons as tfa
tf.__version__
# Out:
# '2.3.0'

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import (LinearLocator, MultipleLocator, FormatStrFormatter)
from matplotlib.dates import MONDAY
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
from matplotlib import gridspec
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %% [markdown]
# # Hyperparameters

# %%
BEST_PATH = './models/lstm_raw.h5'
TRAINING_EPOCHS = 200
LEARNING_RATE = 0.002
EPSILON = 1e-06
BATCH_SIZE = 16

# %% [markdown]
# # Data loading

# %%
l = np.load('./results/2020_W/fw_ct_dataset.npz', allow_pickle=True)
data_indices = l['data_indices']
input_data = l['input_data']
output_label = l['output_label']
INPUT_MAXS = l['INPUT_MAXS']
INPUT_MINS = l['INPUT_MINS']
OUTPUT_MAX = l['OUTPUT_MAX']
OUTPUT_MIN = l['OUTPUT_MIN']

# %%
input_data = input_data.astype('float32')
output_label = output_label.astype('float32')

# %%
print(input_data.shape)
print(output_label.shape)
# Out:
# (456, 144, 9)
# (456, 1)

# %%
print(INPUT_MAXS)
print(INPUT_MINS)
# Out:
# [  41.4725   99.     1313.3      78.755     7.857     4.908    35.39
#    55.877    16.802 ]
# [11.5    16.435  -0.5957 63.447   0.205   0.112  11.53   40.295  11.506 ]

# %%
print(OUTPUT_MAX)
print(OUTPUT_MIN)
# Out:
# 1.9478683859198707
# 0.4452854713085716

# %%
data_indices, input_data, output_label = shuffle(data_indices, input_data, output_label, random_state=3101)

# %%
N_TRAIN = int(input_data.shape[0]*.1/3)
N_DEV = int(input_data.shape[0]/3)
TRAIN_INDEX = [_ for _ in range(N_TRAIN)] + \
              [_ for _ in range(N_DEV, N_DEV+N_TRAIN)] + \
              [_ for _ in range(N_DEV*2, N_DEV*2+N_TRAIN)]
VAL_INDEX = [_ for _ in range(input_data.shape[0]) if _ not in TRAIN_INDEX]
train_input = input_data[TRAIN_INDEX, ...]
train_label = output_label[TRAIN_INDEX, ...]
train_indices = data_indices[TRAIN_INDEX]
val_input = input_data[VAL_INDEX, ...]
val_label = output_label[VAL_INDEX, ...]
val_indices = data_indices[VAL_INDEX]

# %%
print(f'number of data set: {input_data.shape[0]}')
print(f'number of training set: {train_input.shape[0]}')
print(f'number of validation set: {val_input.shape[0]}')
# Out:
# number of data set: 456
# number of training set: 45
# number of validation set: 411

# %%
with strategy.scope():
    train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
    train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)
    val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
    val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)

# %% [markdown]
# # Model construction

# %%
with strategy.scope():
    model = models.Sequential([
        layers.Bidirectional(layers.LSTM(256)),
        layers.LayerNormalization(),
        layers.Dense(32),
        layers.Dense(1)
    ])

# %%
cbs = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=.5, patience=2, verbose=0, mode='min',
    min_delta=0.0001, cooldown=0, min_lr=0)

save = callbacks.ModelCheckpoint(
    BEST_PATH, monitor='val_loss', verbose=0,
    save_best_only=True, save_weights_only=True, mode='min', save_freq='epoch')

early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=20)

# %%
with strategy.scope():
    opt = optimizers.Adam(learning_rate=LEARNING_RATE, epsilon=EPSILON)
    model.compile(optimizer=opt, loss='mae')
    model.fit(train_dataset, epochs=TRAINING_EPOCHS, validation_data=val_dataset,
                  verbose=1, callbacks=[cbs, save, early_stop])
# Out:
# Epoch 1/200
# WARNING:tensorflow:From /home/phil/.virtualenvs/tf20/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 3/3 [==============================] - ETA: 0s - loss: 10.0227INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 3/3 [==============================] - 3s 888ms/step - loss: 10.0227 - val_loss: 0.5639
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 2/200
# 3/3 [==============================] - 1s 186ms/step - loss: 5.8910 - val_loss: 6.5628
# Epoch 3/200
# 3/3 [==============================] - 1s 190ms/step - loss: 3.6508 - val_loss: 2.2880
# Epoch 4/200
# 3/3 [==============================] - 1s 195ms/step - loss: 2.1206 - val_loss: 0.5986
# Epoch 5/200
# 3/3 [==============================] - 1s 188ms/step - loss: 0.7989 - val_loss: 1.3568
# Epoch 6/200
# 3/3 [==============================] - 1s 190ms/step - loss: 1.1531 - val_loss: 0.6335
# Epoch 7/200
# 3/3 [==============================] - 1s 199ms/step - loss: 0.3911 - val_loss: 0.4734
# Epoch 8/200
# 3/3 [==============================] - 1s 195ms/step - loss: 0.5423 - val_loss: 0.2275
# Epoch 9/200
# 3/3 [==============================] - 1s 195ms/step - loss: 0.2775 - val_loss: 0.5174
# Epoch 10/200
# 3/3 [==============================] - 1s 199ms/step - loss: 0.3805 - val_loss: 0.1654
# Epoch 11/200
# 3/3 [==============================] - 1s 188ms/step - loss: 0.2156 - val_loss: 0.2098
# Epoch 12/200
# 3/3 [==============================] - 1s 186ms/step - loss: 0.2004 - val_loss: 0.2345
# Epoch 13/200
# 3/3 [==============================] - 1s 197ms/step - loss: 0.1901 - val_loss: 0.1598
# Epoch 14/200
# 3/3 [==============================] - 1s 198ms/step - loss: 0.1662 - val_loss: 0.1510
# Epoch 15/200
# 3/3 [==============================] - 1s 195ms/step - loss: 0.1717 - val_loss: 0.1315
# Epoch 16/200
# 3/3 [==============================] - 1s 187ms/step - loss: 0.1297 - val_loss: 0.1666
# Epoch 17/200
# 3/3 [==============================] - 1s 197ms/step - loss: 0.1405 - val_loss: 0.1181
# Epoch 18/200
# 3/3 [==============================] - 1s 195ms/step - loss: 0.1173 - val_loss: 0.1144
# Epoch 19/200
# 3/3 [==============================] - 1s 195ms/step - loss: 0.1285 - val_loss: 0.1055
# Epoch 20/200
# 3/3 [==============================] - 1s 187ms/step - loss: 0.1256 - val_loss: 0.1560
# Epoch 21/200
# 3/3 [==============================] - 1s 191ms/step - loss: 0.1110 - val_loss: 0.1097
# Epoch 22/200
# 3/3 [==============================] - 1s 197ms/step - loss: 0.1287 - val_loss: 0.0943
# Epoch 23/200
# 3/3 [==============================] - 1s 187ms/step - loss: 0.1006 - val_loss: 0.1273
# Epoch 24/200
# 3/3 [==============================] - 1s 188ms/step - loss: 0.1093 - val_loss: 0.1086
# Epoch 25/200
# 3/3 [==============================] - 1s 209ms/step - loss: 0.0902 - val_loss: 0.0926
# Epoch 26/200
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0895 - val_loss: 0.0895
# Epoch 27/200
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0888 - val_loss: 0.0943
# Epoch 28/200
# 3/3 [==============================] - 1s 187ms/step - loss: 0.0936 - val_loss: 0.1041
# Epoch 29/200
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0868 - val_loss: 0.0940
# Epoch 30/200
# 3/3 [==============================] - 1s 198ms/step - loss: 0.0825 - val_loss: 0.0876
# Epoch 31/200
# 3/3 [==============================] - 1s 197ms/step - loss: 0.0841 - val_loss: 0.0852
# Epoch 32/200
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0841 - val_loss: 0.0854
# Epoch 33/200
# 3/3 [==============================] - 1s 188ms/step - loss: 0.0820 - val_loss: 0.0893
# Epoch 34/200
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0798 - val_loss: 0.0911
# Epoch 35/200
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0803 - val_loss: 0.0914
# Epoch 36/200
# 3/3 [==============================] - 1s 187ms/step - loss: 0.0795 - val_loss: 0.0897
# Epoch 37/200
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0792 - val_loss: 0.0878
# Epoch 38/200
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0788 - val_loss: 0.0872
# Epoch 39/200
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0788 - val_loss: 0.0871
# Epoch 40/200
# 3/3 [==============================] - 1s 195ms/step - loss: 0.0787 - val_loss: 0.0872
# Epoch 41/200
# 3/3 [==============================] - 1s 188ms/step - loss: 0.0786 - val_loss: 0.0874
# Epoch 42/200
# 3/3 [==============================] - 1s 188ms/step - loss: 0.0785 - val_loss: 0.0874
# Epoch 43/200
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0785 - val_loss: 0.0874
# Epoch 44/200
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0785 - val_loss: 0.0875
# Epoch 45/200
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0784 - val_loss: 0.0875
# Epoch 46/200
# 3/3 [==============================] - 1s 196ms/step - loss: 0.0784 - val_loss: 0.0875
# Epoch 47/200
# 3/3 [==============================] - 1s 188ms/step - loss: 0.0784 - val_loss: 0.0875
# Epoch 48/200
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0784 - val_loss: 0.0876
# Epoch 49/200
# 3/3 [==============================] - 1s 193ms/step - loss: 0.0784 - val_loss: 0.0876
# Epoch 50/200
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0784 - val_loss: 0.0876
# Epoch 51/200
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0784 - val_loss: 0.0876

# %%
model.load_weights(BEST_PATH)

# %%
model.evaluate(val_dataset)
# Out:
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0852
# 0.08515775948762894

# %%
pred_output = model.predict(val_input)

# %%
pred_output = pred_output*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN
val_label = val_label*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(val_label, pred_output, 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df = pd.DataFrame(val_label, index=val_indices[:, 0], columns=['label'])
pred_df['pred'] = pred_output
pred_df.index = pd.DatetimeIndex(pred_df.index)
pred_df = pred_df.sort_index()

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(pred_df.index, pred_df['label'], '-o', ms=5, mec='k', c=cmap[4])
ax0.plot(pred_df.index, pred_df['pred'], 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df.to_csv('./results/model_output/lstm_raw.csv')
