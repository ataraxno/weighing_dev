# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)
from sklearn.utils import shuffle

from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import *
import tensorflow_addons as tfa
tf.__version__
# Out:
# '2.3.0'

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import (LinearLocator, MultipleLocator, FormatStrFormatter)
from matplotlib.dates import MONDAY
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
from matplotlib import gridspec
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %% [markdown]
# # Hyperparameters

# %%
BEST_PATH = './models/ffnn.h5'
TRAINING_EPOCHS = 200
LEARNING_RATE = 0.001
EPSILON = 1e-06
BATCH_SIZE = 16

# %% [markdown]
# # Data loading

# %%
l = np.load('./results/2020_S/fw_dataset.npz', allow_pickle=True)
data_indices = l['data_indices']
input_data = l['input_data']
output_label = l['output_label']
INPUT_MAXS = l['INPUT_MAXS']
INPUT_MINS = l['INPUT_MINS']
OUTPUT_MAX = l['OUTPUT_MAX']
OUTPUT_MIN = l['OUTPUT_MIN']

# %%
input_data = input_data.astype('float32')
output_label = output_label.astype('float32')

# %%
input_data = input_data.reshape(input_data.shape[0], -1)

# %%
print(input_data.shape)
print(output_label.shape)
# Out:
# (363, 1296)
# (363, 1)

# %%
print(INPUT_MAXS)
print(INPUT_MINS)
# Out:
# [ 42.31875  90.9425  330.1      73.335    10.006     5.057    36.58
#   50.264    19.731  ]
# [15.83875  4.4325  -0.5957  32.115    2.296    0.579   15.7      8.744
#  11.393  ]

# %%
print(OUTPUT_MAX)
print(OUTPUT_MIN)
# Out:
# 2.470441467376113
# 0.40038664002968494

# %%
data_indices, input_data, output_label = shuffle(data_indices, input_data, output_label, random_state=3101)

# %%
N_TRAIN = int(input_data.shape[0]*.7)
train_input = input_data[:N_TRAIN, ...]
train_label = output_label[:N_TRAIN, ...]
train_indices = data_indices[:N_TRAIN]
val_input = input_data[N_TRAIN:, ...]
val_label = output_label[N_TRAIN:, ...]
val_indices = data_indices[N_TRAIN:]

# %%
print(f'number of training set: {train_input.shape[0]}')
print(f'number of validation set: {val_input.shape[0]}')
# Out:
# number of training set: 254
# number of validation set: 109

# %%
with strategy.scope():
    train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
    train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)
    val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
    val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)

# %% [markdown]
# # Model construction

# %%
with strategy.scope():
    model = models.Sequential([
        layers.Dense(512, activation=tf.nn.sigmoid),
        layers.BatchNormalization(),
        layers.Dense(512, activation=tf.nn.sigmoid),
        layers.BatchNormalization(),
        layers.Dense(32),
        layers.Dense(1)
    ])

# %%
cbs = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=.5, patience=2, verbose=0, mode='min',
    min_delta=0.0001, cooldown=0, min_lr=0)

save = callbacks.ModelCheckpoint(
    BEST_PATH, monitor='val_loss', verbose=0,
    save_best_only=True, save_weights_only=True, mode='min', save_freq='epoch')

early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=20)

# %%
with strategy.scope():
    opt = optimizers.Adam(learning_rate=LEARNING_RATE, epsilon=EPSILON)
    model.compile(optimizer=opt, loss='mae')
    model.fit(train_dataset, epochs=TRAINING_EPOCHS, validation_data=val_dataset,
                  verbose=1, callbacks=[cbs, save, early_stop])
# Out:
# Epoch 1/200
# WARNING:tensorflow:From /home/phil/.virtualenvs/tf20/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 12 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 15/16 [===========================>..] - ETA: 0s - loss: 2.5281INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 16/16 [==============================] - 2s 109ms/step - loss: 2.4311 - val_loss: 0.2936
# Epoch 2/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.4714 - val_loss: 0.2258
# Epoch 3/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.2893 - val_loss: 0.2124
# Epoch 4/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5895 - val_loss: 0.1870
# Epoch 5/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.3221 - val_loss: 0.1805
# Epoch 6/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.4413 - val_loss: 0.1902
# Epoch 7/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.4861 - val_loss: 0.2282
# Epoch 8/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.2943 - val_loss: 0.1138
# Epoch 9/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1829 - val_loss: 0.2406
# Epoch 10/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1723 - val_loss: 0.2332
# Epoch 11/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1554 - val_loss: 0.2103
# Epoch 12/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1135 - val_loss: 0.1685
# Epoch 13/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1057 - val_loss: 0.2054
# Epoch 14/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0945 - val_loss: 0.1593
# Epoch 15/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1110 - val_loss: 0.1824
# Epoch 16/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0904 - val_loss: 0.1418
# Epoch 17/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1112 - val_loss: 0.1649
# Epoch 18/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1116 - val_loss: 0.1546
# Epoch 19/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1226 - val_loss: 0.1326
# Epoch 20/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1025 - val_loss: 0.1775
# Epoch 21/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0973 - val_loss: 0.1283
# Epoch 22/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0898 - val_loss: 0.1222
# Epoch 23/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1072 - val_loss: 0.1085
# Epoch 24/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0939 - val_loss: 0.1035
# Epoch 25/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1160 - val_loss: 0.1005
# Epoch 26/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1024 - val_loss: 0.0966
# Epoch 27/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0747 - val_loss: 0.0953
# Epoch 28/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0920 - val_loss: 0.0939
# Epoch 29/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1089 - val_loss: 0.0802
# Epoch 30/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0853 - val_loss: 0.0755
# Epoch 31/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0877 - val_loss: 0.0680
# Epoch 32/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0881 - val_loss: 0.0515
# Epoch 33/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1034 - val_loss: 0.0563
# Epoch 34/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0799 - val_loss: 0.0525
# Epoch 35/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0858 - val_loss: 0.0431
# Epoch 36/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0920 - val_loss: 0.0439
# Epoch 37/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1029 - val_loss: 0.0492
# Epoch 38/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1052 - val_loss: 0.0456
# Epoch 39/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1217 - val_loss: 0.0419
# Epoch 40/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0949 - val_loss: 0.0382
# Epoch 41/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0900 - val_loss: 0.0354
# Epoch 42/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0902 - val_loss: 0.0338
# Epoch 43/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0886 - val_loss: 0.0325
# Epoch 44/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0953 - val_loss: 0.0326
# Epoch 45/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0852 - val_loss: 0.0312
# Epoch 46/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1046 - val_loss: 0.0315
# Epoch 47/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0953 - val_loss: 0.0316
# Epoch 48/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0929 - val_loss: 0.0323
# Epoch 49/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0889 - val_loss: 0.0322
# Epoch 50/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0774 - val_loss: 0.0326
# Epoch 51/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1067 - val_loss: 0.0327
# Epoch 52/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0993 - val_loss: 0.0334
# Epoch 53/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0834 - val_loss: 0.0333
# Epoch 54/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0966 - val_loss: 0.0330
# Epoch 55/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0848 - val_loss: 0.0329
# Epoch 56/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0961 - val_loss: 0.0334
# Epoch 57/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0842 - val_loss: 0.0334
# Epoch 58/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0981 - val_loss: 0.0332
# Epoch 59/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1209 - val_loss: 0.0353
# Epoch 60/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1003 - val_loss: 0.0344
# Epoch 61/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0983 - val_loss: 0.0355
# Epoch 62/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0836 - val_loss: 0.0344
# Epoch 63/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0954 - val_loss: 0.0342
# Epoch 64/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0922 - val_loss: 0.0350
# Epoch 65/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0943 - val_loss: 0.0337

# %%
model.load_weights(BEST_PATH)

# %%
model.evaluate(val_dataset)
# Out:
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0314
# 0.03143559396266937

# %%
pred_output = model.predict(val_input)

# %%
pred_output = pred_output*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN
val_label = val_label*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(val_label, pred_output, 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df = pd.DataFrame(val_label, index=val_indices[:, 0], columns=['label'])
pred_df['pred'] = pred_output
pred_df.index = pd.DatetimeIndex(pred_df.index)
pred_df = pred_df.sort_index()

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(pred_df.index, pred_df['label'], '-o', ms=5, mec='k', c=cmap[4])
ax0.plot(pred_df.index, pred_df['pred'], 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df.to_csv('./results/model_output/ffnn.csv')
