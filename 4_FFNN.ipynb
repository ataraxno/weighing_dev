# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)
from sklearn.utils import shuffle

from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import *
import tensorflow_addons as tfa
tf.__version__
# Out:
# '2.3.0'

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import (LinearLocator, MultipleLocator, FormatStrFormatter)
from matplotlib.dates import MONDAY
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
from matplotlib import gridspec
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %% [markdown]
# # Hyperparameters

# %%
BEST_PATH = './models/ffnn.h5'
TRAINING_EPOCHS = 200
LEARNING_RATE = 0.002
EPSILON = 1e-06
BATCH_SIZE = 16

# %% [markdown]
# # Data loading

# %%
l = np.load('./results/2020_S/fw_dataset.npz', allow_pickle=True)
data_indices = l['data_indices']
input_data = l['input_data']
output_label = l['output_label']
INPUT_MAXS = l['INPUT_MAXS']
INPUT_MINS = l['INPUT_MINS']
OUTPUT_MAX = l['OUTPUT_MAX']
OUTPUT_MIN = l['OUTPUT_MIN']

# %%
input_data = input_data.astype('float32')
output_label = output_label.astype('float32')

# %%
input_data = input_data.reshape(input_data.shape[0], -1)

# %%
print(input_data.shape)
print(output_label.shape)
# Out:
# (363, 1296)
# (363, 1)

# %%
print(INPUT_MAXS)
print(INPUT_MINS)
# Out:
# [ 42.31875  90.9425  330.1      73.335    10.006     5.057    36.58
#   50.264    19.731  ]
# [15.83875  4.4325  -0.5957  32.115    2.296    0.579   15.7      8.744
#  11.393  ]

# %%
print(OUTPUT_MAX)
print(OUTPUT_MIN)
# Out:
# 2.470441467376113
# 0.40038664002968494

# %%
data_indices, input_data, output_label = shuffle(data_indices, input_data, output_label, random_state=3101)

# %%
N_TRAIN = int(input_data.shape[0]*.8)
train_input = input_data[:N_TRAIN, ...]
train_label = output_label[:N_TRAIN, ...]
train_indices = data_indices[:N_TRAIN]
val_input = input_data[N_TRAIN:, ...]
val_label = output_label[N_TRAIN:, ...]
val_indices = data_indices[N_TRAIN:]

# %%
print(f'number of training set: {train_input.shape[0]}')
print(f'number of validation set: {val_input.shape[0]}')
# Out:
# number of training set: 290
# number of validation set: 73

# %%
with strategy.scope():
    train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
    train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)
    val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
    val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*10).batch(BATCH_SIZE, drop_remainder=False)

# %% [markdown]
# # Model construction

# %%
with strategy.scope():
    model = models.Sequential([
        layers.Dense(512, activation=tf.nn.sigmoid),
        layers.BatchNormalization(),
        layers.Dense(512, activation=tf.nn.sigmoid),
        layers.BatchNormalization(),
        layers.Dense(1)
    ])

# %%
cbs = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=.5, patience=2, verbose=0, mode='min',
    min_delta=0.0001, cooldown=0, min_lr=0)

save = callbacks.ModelCheckpoint(
    BEST_PATH, monitor='val_loss', verbose=0,
    save_best_only=True, save_weights_only=True, mode='min', save_freq='epoch')

early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=20)

# %%
with strategy.scope():
    opt = optimizers.Adam(learning_rate=LEARNING_RATE, epsilon=EPSILON)
    model.compile(optimizer=opt, loss='mae')
    model.fit(train_dataset, epochs=TRAINING_EPOCHS, validation_data=val_dataset,
                  verbose=1, callbacks=[cbs, save, early_stop])
# Out:
# Epoch 1/200
# WARNING:tensorflow:From /home/phil/.virtualenvs/tf20/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 10 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 10 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 13/19 [===================>..........] - ETA: 0s - loss: 2.1547INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 19/19 [==============================] - 2s 85ms/step - loss: 1.7359 - val_loss: 0.6029
# Epoch 2/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4974 - val_loss: 0.6496
# Epoch 3/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2208 - val_loss: 0.4203
# Epoch 4/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1684 - val_loss: 0.2818
# Epoch 5/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1646 - val_loss: 0.4261
# Epoch 6/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1769 - val_loss: 0.5048
# Epoch 7/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2157 - val_loss: 0.2629
# Epoch 8/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1228 - val_loss: 0.3360
# Epoch 9/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1204 - val_loss: 0.2698
# Epoch 10/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1024 - val_loss: 0.2311
# Epoch 11/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1177 - val_loss: 0.1888
# Epoch 12/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1046 - val_loss: 0.2122
# Epoch 13/200
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1001 - val_loss: 0.1460
# Epoch 14/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1139 - val_loss: 0.2471
# Epoch 15/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1248 - val_loss: 0.2213
# Epoch 16/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1062 - val_loss: 0.0910
# Epoch 17/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1081 - val_loss: 0.1994
# Epoch 18/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1105 - val_loss: 0.0593
# Epoch 19/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1210 - val_loss: 0.1054
# Epoch 20/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1062 - val_loss: 0.0755
# Epoch 21/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1059 - val_loss: 0.0833
# Epoch 22/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0919 - val_loss: 0.0622
# Epoch 23/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0945 - val_loss: 0.1007
# Epoch 24/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1011 - val_loss: 0.0441
# Epoch 25/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0981 - val_loss: 0.0707
# Epoch 26/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0858 - val_loss: 0.0425
# Epoch 27/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0952 - val_loss: 0.0475
# Epoch 28/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0871 - val_loss: 0.0403
# Epoch 29/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0879 - val_loss: 0.0249
# Epoch 30/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0944 - val_loss: 0.0360
# Epoch 31/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0835 - val_loss: 0.0388
# Epoch 32/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1108 - val_loss: 0.0257
# Epoch 33/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1008 - val_loss: 0.0315
# Epoch 34/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0917 - val_loss: 0.0333
# Epoch 35/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0860 - val_loss: 0.0283
# Epoch 36/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0931 - val_loss: 0.0257
# Epoch 37/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0781 - val_loss: 0.0256
# Epoch 38/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0973 - val_loss: 0.0289
# Epoch 39/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1044 - val_loss: 0.0310
# Epoch 40/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0861 - val_loss: 0.0295
# Epoch 41/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0915 - val_loss: 0.0320
# Epoch 42/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0906 - val_loss: 0.0318
# Epoch 43/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1061 - val_loss: 0.0310
# Epoch 44/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0975 - val_loss: 0.0334
# Epoch 45/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0923 - val_loss: 0.0311
# Epoch 46/200
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0867 - val_loss: 0.0316
# Epoch 47/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0859 - val_loss: 0.0324
# Epoch 48/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0924 - val_loss: 0.0327
# Epoch 49/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0930 - val_loss: 0.0313

# %%
model.load_weights(BEST_PATH)

# %%
model.evaluate(val_dataset)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0254
# 0.025421585887670517

# %%
pred_output = model.predict(val_input)

# %%
pred_output = pred_output*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN
val_label = val_label*(OUTPUT_MAX - OUTPUT_MIN) + OUTPUT_MIN

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(val_label, pred_output, 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df = pd.DataFrame(val_label, index=val_indices[:, 0], columns=['label'])
pred_df['pred'] = pred_output
pred_df.index = pd.DatetimeIndex(pred_df.index)
pred_df = pred_df.sort_index()

# %%
fig = plt.figure(figsize=((8.5/2.54*2), (6/2.54*2)))
ax0 = plt.subplot()

ax0.spines['right'].set_visible(False)
ax0.spines['left'].set_position(('outward', 5))
ax0.spines['bottom'].set_position(('outward', 5))

ax0.plot(pred_df.index, pred_df['label'], '-o', ms=5, mec='k', c=cmap[4])
ax0.plot(pred_df.index, pred_df['pred'], 'o', ms=5, mec='k', c=cmap[0])


fig.tight_layout()

# %%
pred_df.to_csv('./results/model_output/ffnn.csv')
